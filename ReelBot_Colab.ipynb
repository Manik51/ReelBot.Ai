# %% [markdown]
# # 🎬 ReelBot.Ai - 1-Click Fast Cloud Runner
# 👉 [Ngrok Auth Token নিন এখান থেকে](https://dashboard.ngrok.com/get-started/your-authtoken)

# %%
#@title 🚀 প্রয়োজনীয় তথ্য বসিয়ে Play (▶) বাটনে চাপুন
NGROK_AUTH_TOKEN = "" #@param {type:"string"}
GEMINI_API_KEY = "" #@param {type:"string"}
PEXELS_API_KEY = "" #@param {type:"string"}

import os
import subprocess
import time

if not os.path.exists("ReelBot.Ai"):
    print("📦 Downloading ReelBot.Ai...")
    # !git clone https://github.com/Manik51/ReelBot.Ai.git
    # %cd ReelBot.Ai
else:
    # %cd /content/ReelBot.Ai
    # !git pull

print("⚙️ Installing dependencies...")
# !pip install -q -r requirements.txt
# !pip install -q pyngrok uvicorn

os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY
os.environ["PEXELS_API_KEY"] = PEXELS_API_KEY

from pyngrok import ngrok
if NGROK_AUTH_TOKEN:
    ngrok.set_auth_token(NGROK_AUTH_TOKEN)

process = subprocess.Popen(["uvicorn", "backend.app:app", "--host", "0.0.0.0", "--port", "8000"])
time.sleep(4)

public_url = ngrok.connect(8000)
print("\n=======================================================")
print(f"🎉 আপনার লাইভ ReelBot UI লিঙ্ক: {public_url}")
print("=======================================================\n")
